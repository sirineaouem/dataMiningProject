# %% [markdown]
# <img src="twitter_class.png"  width="300" height="400" align=right>
# <p style="font-size:50px;color:#b34d4d">Projet fouille de données</p>
# <h3 style="color:#b34d66">thème Classification des tweets</h3>
# <h2 style="color:#4db380"> réalisé par: Aouem Sirine </h2>
# <h2 style="color:#b34d66"> 3DNI1 </h2>

# %% [markdown]
# <b style="font-size:18px;">Les objectifs de se projet consiste à:</b>
# <p>•Maitriser l’API de twitter pour l’extraction des tweets</p>
# <p>•Maitriser la partie NLP (naturallanguageprocessing) avec NLTK en Python</p>
# <p>•Appliquer les principes de nettoyage des données</p>
# <p>•Classer les tweets: regrouper ensemble les tweets qui sont similaires.C’est une étape qui peut être considérée comme une étape</p>

# %% [markdown]
# <b style="font-size:18px;">Introduction</b>

# %% [markdown]
# <p>De nombreuses conversations intéressantes se déroulent sur Twitter, et il peut être difficile de trouver les plus pertinentes . Les sujets peuvent vous y aider mais il est presque impossible de suivre toutes l'actualité, les nouvelles et les tweets donc il devient très important d'avoir un résumé à propos tout ce qui deroulent: d'ou on est demandé de réaliser une application qu’on peut utilisé pour classer les tweets sous form  de groupes de sorte à ce qu’on présente à l’utilisateur un seul Tweet de chaque group.</P>

# %% [markdown]
# <p>ce projet est dévisé en trois partie: </p>
# <p>•Prétraitement des tweets</p>
# <p>•Traitement destweets: NLP (Natural LanguageProcessing)</p>
# <p>•Classification des tweets</p>

# %% [markdown]
# <b style="font-size:20px;color:#ff4d4d;"> Partie I:Prétraitement des tweets</b>

# %% [markdown]
# <p>Dans cette partie, on amené à nettoyé les données collecté afin d’éliminer le texte inutile des tweets tels que les #, les noms des utilisateurs,les url,les emojis ...</p>

# %% [markdown]
# <p>avant de commencer il faut tout d'abord de creér un compte twitter developper afin d'avoir l'acces à télécharger les tweets d'ou on obient la clé et l'acées à l'api twitter our q'on puisse traiter les données </p>

# %% [markdown]
# <b style="font-size:18px;color:#43ff79;">Collecte des données:</p>

# %% [markdown]
# </p>on commence par installer les bibliothèques liée a twitter: tweety,tweepy et twitter par les commande ci-dessous:<p>

# %%
# Import the required libraries.
import tweepy
import pandas as pd
import matplotlib.pyplot as plt


consumer_key = "Tippg04Ns8bfIZtE3uMprKEym" 
consumer_secret = "qHjBkD4CBX67rHPenKu96c7W5Tsv59t9BGBVsm0pXM0oLatOS8"
access_key= "1328070400136400905-ZOCtds4L0DD3LqMJ2r9rZHSyAi75Xu"
access_secret = "qX3pBBD42A1dAZDPXx2DGcH0T0hcr4e5Oxw40YwR9wTnc"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

result=[]

for tweet in tweepy.Cursor(api.search,q="#",
                           lang="en",
                           since="2020-01-01").items(15000):
    result.append(tweet)
    #print (tweet.created_at, tweet.text)
    leng= len(result)
print(leng)

# %%
i=0

for tweet in tweepy.Cursor(api.search,q="#",
                           lang="en",
                           since="2020-01-01").items(15000):
    twitter_data.loc[i,"text"] = tweet.text
    i+=1

# %%
import csv
twitter_data.to_csv('twitterData.csv',index = False)

# %%
twitter_data = pd.read_csv('twitterData.csv')

# %%
print(twitter_data.shape)
# Out:
# (15000, 1)

# %% [markdown]
# <p> on enregistre le data frame obtenu à  partir de l'api twitter sous forme d'un fichier csv</p>

# %% [markdown]
# <p> pour s'assurer qu'on n'a pas pas des tweets vides on tape la commande suivante </p>

# %%
twitter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    15000 non-null  object
# dtypes: object(1)
# memory usage: 117.3+ KB

# %% [markdown]
# <p>on a obtenu des tweets brutes qui contiennet beaucoup des données unitiles </p>

# %%
twitter_data.head(10)
# Out:
#                                                 text
# 0  RT @chynxoxo: Build a team \nSo strong\nYou do...
# 1                 @CaptainOskarSTO a long, long time
# 2  Congrats: 1st Team Offense:\nBrandon Goodman -...
# 3  mad I can't call tom a simp in the twitch chat...
# 4                    WHAAAAT https://t.co/K4Ufjxelsz
# 5        RT @Zariinaa_: no I still got the nasty one
# 6  @donwinslow @realDonaldTrump He's a TRAITOR! 😷...
# 7  @tommycollison @LambdaSchool Exciting! Congrat...
# 8  oh come on even I know that’s not the real pik...
# 9  My grandfather often helped feed the prisoners...

# %% [markdown]
# <p> on est ammené maintenat à netoyant les données </P>

# %% [markdown]
# <b style="font-size:18px;color:#43ff79;">Pretraitement des données:</p>

# %% [markdown]
# <p>dans cette partie on va utilisé RegEx</p>

# %% [markdown]
# <p>Un RegEx, ou expression régulière, est une séquence de caractères qui forme un modèle de recherche.
#
# Le RegEx peut être utilisé pour vérifier si une chaîne contient le modèle de recherche spécifié.</p>

# %% [markdown]
# <p>Python possède un paquet intégré appelé re, qui peut être utilisé pour travailler avec des expressions régulières.</p>

# %% [markdown]
# <p> Dans re.sub(), on spécifie un modèle d'expression régulière dans le premier argument, une nouvelle chaîne dans le deuxième argument, et une chaîne à traiter dans le troisième argument</p>

# %% [markdown]
# <p>Nous pouvons combiner un modèle d'expression régulière en objets de type "pattern", qui peuvent être utilisés pour la comparaison de modèles. Il est également possible de rechercher à nouveau un modèle sans le réécrire grace la fonction re.compile</p>

# %% [markdown]
# <p>maintenant on commence à nettoyer les données en éliminant les donees unitiles </p>

# %%
import re
for index, row in twitter_data.iterrows():
    text= row['text']
    httpdata= re.sub(r"http\S+", "", text)
    
    hashdata = re.sub(r"#\S+", "", httpdata)
    atdata = re.sub(r"@\S+", "", hashdata)
    brdata = re.sub(r"\n+", "", atdata)
    rtdata = re.sub(r"RT+", "", brdata)
    numddata = re.sub('[0-9]+', "", rtdata)
    laughdata = re.sub("hhh+", '', rtdata)
    emoji = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    newdata = re.sub(emoji, "", laughdata)
    twitter_data.loc[index,'text'] =newdata

# %% [markdown]
# <p> apres avoir nettoyer les données on peut vérifier s'ils sont prêtes pour être traitées </p>

# %%
twitter_data.head(15)
# Out:
#                                                  text
# 0     Build a team So strongYou don't know who the...
# 1                                   a long, long time
# 2    Congrats: 1st Team Offense:Brandon Goodman - RB
# 3   mad I can't call tom a simp in the twitch chat...
# 4                                            WHAAAAT
# 5                        no I still got the nasty one
# 6                                    He's a TRAITOR!
# 7                   Exciting! Congratulations, Tommy!
# 8   oh come on even I know that’s not the real pik...
# 9   My grandfather often helped feed the prisoners...
# 10                                              Omfg
# 11  5A01C654 :Battle IDI need backup!Lvl 150 Tiama...
# 12     it costs $0.00 to share and support an artist
# 13   Didn’t take long at all.  We are back to the ...
# 14   not really what i was going for there at all,...

# %%
twitter_data.to_csv('newTwitterData.csv',index = False)

# %% [markdown]
# <p> vu que les données ne contiennent plus les caractères spéciaux on peut maintenat au traitement </p>

# %% [markdown]
# <b style="font-size:20px;color:#ff4d4d;"> Partie II:Traitement des tweets: NLP (Natural LanguageProcessing)</b>

# %% [markdown]
# <p>Natural Language Toolkit (NLTK) est une boîte-à-outil permettant la création de programmes pour l'analyse de texte.</p>

# %% [markdown]
# <p>pour cette partie on va utiliser la bibliothèque nltk</p>

# %% [markdown]
# <p>La première manipulation souvent effectuée dans le traitement du texte est la suppression de ce qu'on appelle en anglais les stopwords. Ce sont les mots très courants dans la langue étudiée ("and", "a", "the"... ) qui n'apportent pas de valeur informative pour la compréhension du "sens" d'un document et corpus. Il sont très fréquents et ralentissent notre travail : nous souhaitons donc les supprimer.</p>

# %% [markdown]
# <p>Il existe dans la librairie NLTK une liste par défaut des stopwords dans plusieurs langues, nous allons faire ceci d'une autre manière à supprimer les mots les plus fréquents du corpus et considérer qu'il font partie du vocabulaire commun et n'apportent aucune information.</p>

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# ...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aouem\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aouem\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aouem\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# <p>Plus qu'une dernière étape et on en aura terminé avec le prétraitement !
#
# Le processus de « lemmatisation » consiste à représenter les mots (ou « lemmes ») sous leur forme canonique. Par exemple pour un verbe, ce sera son infinitif. Pour un nom, son masculin singulier. L'idée étant encore une fois de ne conserver que le sens des mots utilisés dans le corpus.
#
# Si l'on reprend notre exemple précédent, "Bonjour, je suis un texte d'exemple pour le cours d'Openclassrooms. Soyez attentifs à ce cours !"
#
# L'idéal serait d'extraire les lemmes suivants : « bonjour, être, texte, exemple, cours, openclassrooms, être, attentif, cours ». Dans le processus de lemmatisation, on transforme donc « suis » en « être»  et « attentifs » en « attentif ».</p>

# %%
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
Porter_steamer = PorterStemmer() 
vectorizer = CountVectorizer()
stem_data=[]
for i in range(0,twitter_data.shape[0]):
    stemmed_array=twitter_data['text'][i].split()
    stemmed=[Porter_steamer.stem(word) for word in stemmed_array if not word in set(stopwords.words('english'))]
    stemmed=' '.join(stemmed)
    stem_data.append(stemmed)
print(stem_data[0:20])
# Out:
# ['build team So strongyou know boss', 'long, long time', 'congrats: 1st team offense:brandon goodman - RB', "mad I can't call tom simp twitch chat anymor", 'whaaaat', 'I still got nasti one', "he' traitor!", 'exciting! congratulations, tommy!', 'oh come even I know that’ real pikachu', 'My grandfath often help feed prison short cooks, notic SS would alway dump…', 'omfg', '5a01c654 :battl idi need backup!lvl 150 tiamat malic', 'cost $0.00 share support artist', 'didn’t take long all. We back nonsens shit. but anyth illeg would blurb t…', 'realli go all, think biowar get benefit doubt t…', 'and hade', 'over 42,000 nevada voter vote once.', 'cheeki submiss', "you get 'used' copi 'miss, what doe incomprehens mean?' £7.49 &amp; free delivery…", 'the moment struggl tide, know reach shore anyon else!!!']

# %% [markdown]
# <p> on a affiché les mots racine de 30 tweet</p>

# %% [markdown]
#  <p>CountVectorizer permet de convertir un ensemble de documents textuels en une matrice de comptage de jetons</p>

# %%
matrix =vectorizer.fit_transform(stem_data)
print(matrix)
# Out:
#   (0, 2460)	1
#   (0, 13994)	1
#   (0, 13126)	1
#   (0, 13608)	1
#   (0, 8101)	1
#   (0, 2233)	1
#   (1, 8598)	2
#   (1, 14273)	1
#   (2, 13994)	1
#   (2, 3407)	1
#   (2, 179)	1
#   (2, 10121)	1
#   (2, 2310)	1
#   (2, 6209)	1
#   (2, 11588)	1
#   (3, 8744)	1
#   (3, 2613)	1
#   (3, 2591)	1
#   (3, 14360)	1
#   (3, 12902)	1
#   (3, 14687)	1
#   (3, 2897)	1
#   (3, 1243)	1
#   (4, 15453)	1
#   (5, 13520)	1
#   :	:
#   (14994, 5400)	1
#   (14994, 4014)	1
#   (14995, 15827)	1
#   (14995, 6409)	1
#   (14996, 14273)	1
#   (14996, 5076)	1
#   (14996, 8438)	1
#   (14996, 14941)	2
#   (14996, 2906)	1
#   (14996, 10267)	1
#   (14996, 3147)	1
#   (14996, 963)	1
#   (14996, 473)	1
#   (14997, 1136)	1
#   (14998, 6253)	1
#   (14998, 10196)	1
#   (14998, 3014)	1
#   (14998, 2906)	1
#   (14998, 10326)	1
#   (14998, 12543)	2
#   (14998, 5430)	1
#   (14998, 4840)	1
#   (14998, 3197)	1
#   (14998, 9860)	1
#   (14999, 14602)	1

# %% [markdown]
# chaque mot a été representé sous forme d'un vecteur (indice de tweet, nombre d'occurence de mot dans tout le dataset)

# %% [markdown]
# <b style="font-size:20px;color:#ff4d4d;"> Partie III:Classification des tweets</b>

# %% [markdown]
# <p>tant donné un ensemble de tweets, l’objectif est de les résumer sous formes de groupes de sorte à ce que les Tweets qui sont dans le même groupe soient similaires. Ainsi, l’utilisateur pourra par la suite lire juste un Tweet de chaque groupe (le Tweet qui est le centroïde de groupes).</p>

# %% [markdown]
# <p>pour cela on va utiliser la classification k-means: C’est l’un des algorithmes de clustering les plus répandus. Il permet d’analyser un jeu de données caractérisées par un ensemble de descripteurs, afin de regrouper les données “similaires” en groupes (ou clusters).
#
# La similarité entre deux données peut être inférée grâce à la “distance” séparant leurs descripteurs ; ainsi deux données très similaires sont deux données dont les descripteurs sont très proches. Cette définition permet de formuler le problème de partitionnement des données comme la recherche de K “données prototypes”, autour desquelles peuvent être regroupées les autres données.</p>

# %% [markdown]
# <p>on a utiliser l’algorithme K-Means pour  classer  les Tweets  en 30 classes et on va ajouter les vecteurs resultatnt de CountVectorizer commme données pour êtres classifiées  </p>

# %%
from sklearn.cluster import KMeans
dist=[]
for i in range(1,30):
    Kmeans=KMeans(n_clusters=i,
                  init='k-means++',#selects initial cluster centers for k-mean clustering in a smart way to speed up convergence.
                  random_state=0,#Determines random number generation for centroid initialization. Use an int to make the randomness deterministic
                  verbose=True)
    Kmeans.fit(matrix)
    dist.append(Kmeans.inertia_)#Sum of squared distances of samples to their closest cluster center.
# Out:
# Initialization complete
# Iteration 0, inertia 258674.0
# Iteration 1, inertia 108645.48093333277
# Converged at iteration 1: center shift 0.0 within tolerance 4.518704886282502e-08
# Initialization complete
# Iteration 0, inertia 167430.0
# Iteration 1, inertia 108645.48093333277
# Converged at iteration 1: center shift 0.0 within tolerance 4.518704886282502e-08
# Initialization complete
# Iteration 0, inertia 196916.0
# Iteration 1, inertia 108645.48093333277
# Converged at iteration 1: center shift 0.0 within tolerance 4.518704886282502e-08
# Initialization complete
# Iteration 0, inertia 124456.0
# Iteration 1, inertia 108645.48093333277
# Converged at iteration 1: center shift 0.0 within tolerance 4.518704886282502e-08
# Initialization complete
# Iteration 0, inertia 297234.0
# Iteration 1, inertia 108645.48093333277
# Converged at iteration 1: center shift 0.0 within tolerance 4.518704886282502e-08
# Initialization complete
# Iteration 0, inertia 258186.0
# ...

# %% [markdown]
# <p> Pour chaque itération un score a été affiché</p>

# %% [markdown]
# <p>La méthode Elbow est une technique très populaire et l'idée est d'effectuer le k-means clustering  pour un nombre de clusters k  et pour chaque valeur, nous calculons la somme des carrés des distances de chaque point à son centre assigné (distorsions).
#
# Lorsque les distorsions sont tracées et que le graphique ressemble à un bras, le "elbow" (le point d'inflexion de la courbe) est la meilleure valeur de k.</p>

# %%
import matplotlib.pyplot as plt
plt.xlabel('numéro de clusters')
plt.ylabel('distance')
plt.plot(range(1,30),dist)
plt.title('methode elbow')
plt.show()

# %%
true_k=30
Kmeans=KMeans(n_clusters=true_k,init='k-means++',n_init=1)
Kmeans.fit(matrix)
# Out:
# KMeans(n_clusters=30, n_init=1)

# %% [markdown]
# <p>maintenant on va afficher les mots racine essentiels pour chaque cluster comme un résumé de chaque groupeement </p>

# %%
print("les mots essentielles du thème ") 
centroids = Kmeans.cluster_centers_.argsort()[:, ::-1]
mot = vectorizer.get_feature_names()
for i in range(true_k):
    print("dans Cluster %d:" % i)
    for ind in centroids[i, :10]:
        print(' %s' % mot[ind])
    print()
# Out:
# les mots essentielles du thème
# dans Cluster 0:
#  thank
#  god
#  it
#  much
#  the
#  go
#  get
#  everyon
#  realli
#  thi
#
# dans Cluster 1:
#  good
#  custom
#  sell
#  let
#  my
#  tyyyyyme
#  want
#  know
#  cars
#  still
#
# dans Cluster 2:
#  it
#  the
#  like
#  get
#  go
#  thi
#  that
#  need
#  we
#  want
#
# dans Cluster 3:
#  play
#  backer
#  we
#  spi
#  deep
#  quarterback
#  hole
#  mike
#  smith
#  put
#
# dans Cluster 4:
#  man
#  similar
#  cylind
#  ugli
#  look
#  collapse
#  roof
#  either
#  team
#  like
#
# dans Cluster 5:
#  peopl
#  like
#  it
#  don
#  the
#  need
#  help
#  if
#  get
#  know
#
# dans Cluster 6:
#  think
#  pay
#  mind
#  let
#  sit
#  needi
#  tweet
#  done
#  fav
#  faux
#
# dans Cluster 7:
#  love
#  would
#  you
#  it
#  good
#  much
#  help
#  realli
#  check
#  see
#
# dans Cluster 8:
#  one
#  it
#  day
#  no
#  thing
#  like
#  time
#  we
#  the
#  that
#
# dans Cluster 9:
#  got
#  it
#  one
#  like
#  you
#  the
#  all
# ...

# %% [markdown]
# <p>Après  avoir  récupéré  les  classes,on a choisi un  Tweet  par  classe  comme  représentant.  Les  Tweets choisis seront les résumés de toutes les informations contenues dans les Tweets.</p>

# %%
final_twitter_data= pd.DataFrame(columns = [ 'text'])
i=0
j=0
while i<30:
    while True: 
        lastData=vectorizer.transform([stem_data[j]])
        prediction=Kmeans.predict(lastData)
        if i == prediction:
            print("represantant du cluster "+str(prediction)+twitter_data.loc[j,"text"])
            final_twitter_data.loc[i,"text"] =twitter_data.loc[j,"text"]
            j=0
            break
        j+=1
    i+=1
final_twitter_data.to_csv('final_twitter_dataFrame.csv',index = False )
# Out:
# represantant du cluster [0] THANK GOD
# represantant du cluster [1]  I wanted to let you know .. I’m still selling cars.. My customers having a good tyyyyyme!
# represantant du cluster [2]  Build a team So strongYou don't know who the boss is
# represantant du cluster [3]We putting P smith at mike backer play the deep hole  spy  the Quarterback
# represantant du cluster [4]An ugly win. Man, this team can either fire on all cylinders or look like the roof is gonna collapse... similar to…
# represantant du cluster [5]  ...people in Louisville have told me they are terrified. Now that media has died down and the leaders of the people have…
# represantant du cluster [6]  Pay no mind to this needy tweet. Let it sit here and think about what it's done.
# represantant du cluster [7]  Falling in love can act as a painkiller
# represantant du cluster [8]  "I would say it was one of our best performances of the season, personally."The skipper reacts to a relentless performance from…
# ...

# %% [markdown]
# <b style="font-size:18px;">Introduction</b>

# %% [markdown]
# <p>on a effectué quelques étapes essentielles du prétraitement du texte : tokenisation, suppression des stop-words, lemmatisation et stemming. puis on a fait la classification des données et crée de notre ensemble de features des représentatives tout cela va permettre à faciliter la lecture des tweets en donnant un recaputulant ce qui permetra  donner une visibilité sur l'actualité et peut être participer à la prise des décision dans plusieurs cas</p>
