# %% [markdown]
# <p style="font-size:50px;color:#b34d4d">Projet fouille de données</p>
# <h3 style="color:#b34d66">thème Classification des tweets</h3>
# <h2 style="color:#4db380"> réalisé par: Aouem Sirine </h2>
# <h2 style="color:#b34d66"> 3DNI1 </h2>

# %% [markdown]
# <b>Les objectifs de se projet consiste à:</b>
# <p>•Maitriser l’API de twitter pour l’extraction des tweets</p>
# <p>•Maitriser la partie NLP (naturallanguageprocessing) avec NLTK en Python</p>
# <p>•Appliquer les principes de nettoyage des données</p>
# <p>•Classer les tweets: regrouper ensemble les tweets qui sont similaires.C’est une étape qui peut être considérée comme une étape</p>

# %%
pip install tweety
# Out:
# Requirement already satisfied: tweety in c:\users\aouem\anaconda3\lib\site-packages (0.1.6)
# Requirement already satisfied: selenium in c:\users\aouem\anaconda3\lib\site-packages (from tweety) (3.141.0)
# Requirement already satisfied: spacy in c:\users\aouem\anaconda3\lib\site-packages (from tweety) (2.3.5)
# Requirement already satisfied: pandas in c:\users\aouem\anaconda3\lib\site-packages (from tweety) (1.0.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\aouem\anaconda3\lib\site-packages (from tweety) (4.9.1)
# Requirement already satisfied: vaderSentiment in c:\users\aouem\anaconda3\lib\site-packages (from tweety) (3.3.2)
# Requirement already satisfied: chromedriver-binary==74.0.3729.6.0 in c:\users\aouem\anaconda3\lib\site-packages (from tweety) (74.0.3729.6.0)
# Requirement already satisfied: textblob in c:\users\aouem\anaconda3\lib\site-packages (from tweety) (0.15.3)
# Requirement already satisfied: urllib3 in c:\users\aouem\anaconda3\lib\site-packages (from selenium->tweety) (1.25.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (0.8.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (1.18.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (0.7.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (2.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (4.47.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (2.24.0)
# Requirement already satisfied: setuptools in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (49.2.0.post20200714)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (3.0.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (7.4.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\aouem\anaconda3\lib\site-packages (from spacy->tweety) (1.0.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\aouem\anaconda3\lib\site-packages (from pandas->tweety) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\aouem\anaconda3\lib\site-packages (from pandas->tweety) (2.8.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aouem\anaconda3\lib\site-packages (from beautifulsoup4->tweety) (2.0.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\aouem\anaconda3\lib\site-packages (from textblob->tweety) (3.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aouem\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->tweety) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\aouem\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->tweety) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\aouem\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->tweety) (2.10)
# Requirement already satisfied: six>=1.5 in c:\users\aouem\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->tweety) (1.15.0)
# Requirement already satisfied: regex in c:\users\aouem\anaconda3\lib\site-packages (from nltk>=3.1->textblob->tweety) (2020.6.8)
# Requirement already satisfied: click in c:\users\aouem\anaconda3\lib\site-packages (from nltk>=3.1->textblob->tweety) (7.1.2)
# Requirement already satisfied: joblib in c:\users\aouem\anaconda3\lib\site-packages (from nltk>=3.1->textblob->tweety) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-3.9.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\aouem\anaconda3\lib\site-packages (from tweepy) (1.15.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\aouem\anaconda3\lib\site-packages (from tweepy) (2.24.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\aouem\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\aouem\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aouem\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\aouem\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\aouem\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\aouem\anaconda3\lib\site-packages (1.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import tweepy as tw
import matplotlib.pyplot as plt

consumer_key = "Tippg04Ns8bfIZtE3uMprKEym" 
consumer_secret = "qHjBkD4CBX67rHPenKu96c7W5Tsv59t9BGBVsm0pXM0oLatOS8"
access_token= "1328070400136400905-ZOCtds4L0DD3LqMJ2r9rZHSyAi75Xu"
access_token_secret = "qX3pBBD42A1dAZDPXx2DGcH0T0hcr4e5Oxw40YwR9wTnc"

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True, compression=True)

search_words ='#'
date = "2020-11-14" # choose any date with the format "yyyy-mm-dd"
tab =[]
tweets = tw.Cursor(api.search,q=search_words,lang="en",since=date).items(10000)
for tweet in tweets:
    #print(tweet.id,tweet.user.screen_name,tweet.created_at,tweet.text,len(tweet.text))
    tab.append([tweet.id,tweet.user.screen_name,tweet.created_at,tweet.text,len(tweet.text)])
    df = pd.DataFrame(tab).to_csv('tweets',index=False,header=['ID','User','Date','Tweet','Len'])
# Out:
# Rate limit reached. Sleeping for: 367
# Rate limit reached. Sleeping for: 745
# Rate limit reached. Sleeping for: 793
# Rate limit reached. Sleeping for: 762
# Rate limit reached. Sleeping for: 459
# Rate limit reached. Sleeping for: 632

# %%
import pandas as pd
import tweepy

consumer_key = "Tippg04Ns8bfIZtE3uMprKEym" 
consumer_secret = "qHjBkD4CBX67rHPenKu96c7W5Tsv59t9BGBVsm0pXM0oLatOS8"
access_token= "1328070400136400905-ZOCtds4L0DD3LqMJ2r9rZHSyAi75Xu"
access_token_secret = "qX3pBBD42A1dAZDPXx2DGcH0T0hcr4e5Oxw40YwR9wTnc"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
twitter_data= pd.DataFrame(columns = ['text'])
tweets = tweepy.Cursor(api. user_timeline , id="twitter").items( 15000)

# Iterate and print tweets
i=0
for tweet in tweets:
    twitter_data.loc[i,"text"] = tweet.text
    i+=1


import csv
twitter_data.to_csv('twitterCsvFile.csv',index = False)

# %%
print(twitter_data_analysis.shape)
# Out:
# (3226, 1)

# %%
# Import the required libraries.
import tweepy
import pandas as pd
import matplotlib.pyplot as plt


consumer_key = "Tippg04Ns8bfIZtE3uMprKEym" 
consumer_secret = "qHjBkD4CBX67rHPenKu96c7W5Tsv59t9BGBVsm0pXM0oLatOS8"
access_key= "1328070400136400905-ZOCtds4L0DD3LqMJ2r9rZHSyAi75Xu"
access_secret = "qX3pBBD42A1dAZDPXx2DGcH0T0hcr4e5Oxw40YwR9wTnc"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
twitter_data = pd.DataFrame(columns = ['text'])
api = tweepy.API(auth,wait_on_rate_limit=True)


for tweet in tweepy.Cursor(api.search,q="#",
                           lang="en",
                           since="2020-01-01").items(10000):
       twitter_data.loc[i,"text"] = tweet.text
       i+=1
    
    
twitter_data.to_csv('fileCSVtwitter.csv',index = False)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [WinError 10054] Une connexion existante a dû être fermée par l’hôte distant
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     402             if read is False or not self._is_method_retryable(method):
# --> 403                 raise six.reraise(type(error), error, _stacktrace)
#     404             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-24-b4138924ad44> in <module>
#      16
#      17
# ---> 18 for tweet in tweepy.Cursor(api.search,q="#",
#      19                            lang="en",
#      20                            since="2020-01-01").items(10000):
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     217         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     218             # Reached end of current page, get the next page...
# --> 219             self.current_page = self.page_iterator.next()
#     220             while len(self.current_page) == 0:
#     221                 self.current_page = self.page_iterator.next()
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     128
#     129         if self.index >= len(self.results) - 1:
# --> 130             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     131
#     132             if hasattr(self.method, '__self__'):
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~\anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     700                 value = tp()
#     701             if value.__traceback__ is not tb:
# --> 702                 raise value.with_traceback(tb)
#     703             raise value
#     704         finally:
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     182                 # Execute request
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#     186                                                 data=self.post_data,
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# TweepError: Failed to send request: ('Connection aborted.', ConnectionResetError(10054, 'Une connexion existante a dû être fermée par l’hôte distant', None, 10054, None))

# %%
print(result.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-05a94821c073> in <module>
# ----> 1 print(result.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
def toDataFrame(tweets):

    DataSet = pd.DataFrame()
    DataSet['tweetID'] = [tweet.id for tweet in tweets]
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet in tweets]
    DataSet['tweetFavoriteCt'] = [tweet.favorite_count for tweet in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]
    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet  in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet  in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet  in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet in tweets]

    DataSet.to_csv('file1.csv') 

    return DataSet

# %%
#Pass the tweets list to the above function to create a DataFrame
DataSet = toDataFrame(result)

# %%
# Let's check the top 5 records in the Data Set
DataSet.head(20)
# Out:
#                 tweetID                                          tweetText  \
# 0   1338591245631942665  RT @nikola_mixer: for the first time ever... s...
# 1   1338591245615079424  RT @thetopjob: and Scotty was the coal lobby’s...
# 2   1338591245606727683  @FrankRedfoot @PureBrAutist @bailey_moloney @D...
# 3   1338591245606637568  @jbralston The Christ Story is the story of ou...
# 4   1338591245602607106      @azninthesun so she doesn't have a tiny husbo
# 5   1338591245510303745  RT @KHefferon: Chemistree https://t.co/6JRt4u5FFa
# 6   1338591245489344521           RT @DiegoDan5o: Meridian x Coldblooded 🔥
# 7   1338591245397004289  RT @SanaSaeed: happy anniversary to one of the...
# 8   1338591245392896002  No one:\nAbsolutely no one:\nITV: https://t.co...
# 9   1338591245388689413  RT @kyalbr: I saw a tweet where the animation ...
# 10  1338591245388623873  @ciceksenfonisi0 t-thamk you 👉💝👈 https://t.co/...
# 11  1338591245384511496               @rotarydials i know that's not boone
# 12  1338591245380280320  #Towson | Reports have a crash on the IL at th...
# 13  1338591245380112386  RT @ToriNicksWho: $10 Billion in donations &am...
# 14  1338591245371772930  @petitevanity Try chewing some gum. You’d be s...
# 15  1338591245355114498  @wolfboy852001 @CottoGottfried State legislatu...
# 16  1338591245346754564                      Tonic https://t.co/j3jy7GHWku
# 17  1338591245346680837  RT @SilentRunning61: When i go to my local sho...
# 18  1338591245338365960  RT @AndyMc81: Get ready for Monday Night Footb...
# 19  1338591245338284033             @CBSNews My aunt being one of those. 😔
#
#     tweetRetweetCt  tweetFavoriteCt          tweetSource        tweetCreated  \
# 0              353                0  Twitter for Android 2020-12-14 21:06:37
# 1               37                0     Twitter for iPad 2020-12-14 21:06:37
# 2                0                0  Twitter for Android 2020-12-14 21:06:37
# 3                0                0   Twitter for iPhone 2020-12-14 21:06:37
# 4                0                0            TweetDeck 2020-12-14 21:06:37
# 5            37420                0      Twitter Web App 2020-12-14 21:06:37
# 6                0                0   Twitter for iPhone 2020-12-14 21:06:37
# 7             1304                0      Twitter Web App 2020-12-14 21:06:37
# 8                0                0   Twitter for iPhone 2020-12-14 21:06:37
# 9             4251                0   Twitter for iPhone 2020-12-14 21:06:37
# 10               0                0   Twitter for iPhone 2020-12-14 21:06:37
# 11               0                0  Twitter for Android 2020-12-14 21:06:37
# 12               0                0            TweetDeck 2020-12-14 21:06:37
# 13             284                0  Twitter for Android 2020-12-14 21:06:37
# 14               0                0   Twitter for iPhone 2020-12-14 21:06:37
# 15               0                0      Twitter Web App 2020-12-14 21:06:37
# 16               0                0   Twitter for iPhone 2020-12-14 21:06:37
# 17               5                0      Twitter Web App 2020-12-14 21:06:37
# 18               3                0  Twitter for Android 2020-12-14 21:06:37
# 19               0                0   Twitter for iPhone 2020-12-14 21:06:37
#
#                  userID       userScreen                       userName  \
# 0            2539144708     starwarsjade              raika 🎉 #confetti
# 1   1150553499500814339  ElaineM11584892                   Elaine McKay
# 2    950372534544936961     NorthernJook                       Kaiden .
# 3   1333805453424218112      WolfRaven19                     Wolf Raven
# 4             540275586       TalkingHat              Her ExcellentTree
# 5             921913964  AimarVegaFernnd           Aimar Vega Fernández
# 6             424283518           9bills                         9bills
# 7              17886250        EeahKaiju                   NOIZYCAT4DHD
# 8            1035374461    daniellepace_                     Danielle ✨
# 9            2194039585      JeremyPirri                   Jeremy Pirri
# 10  1252351928295739392     sircumferans               Thot Appreciator
# 11           3929115197       damnoiseau                    i'm at soup
# 12   898655123592937472       trafficliz            Traffic Liz Drabick
# 13            271277936  TheePossibility              Almighty Tang San
# 14            803828077     MissBriHines  thee black lil murmaid 😌🧜🏾‍♀️
# 15           2230776414      amymostella                   amy mostella
# 16  1075764586979188736        rubis____                    maman jolie
# 17  1306518534722330624   IAM_Sandilands                    IAM Sandile
# 18            310357046    3rdandLongCFL                   3rd and Long
# 19   904413114073882625        taurini21                        Chelsea
#
#           userCreateDt                                           userDesc  \
# 0  2014-05-10 14:25:49  for every question why, you were my because (f...
# 1  2019-07-14 23:51:45  Left wing nut job, life member of a union, wor...
# 2  2018-01-08 14:24:04  politically homeless, I'm just here for a laugh .
# 3  2020-12-01 16:09:58                   Artist, Talkeetna, Alaska 🇺🇸 𒉌₁₅
# 4  2012-03-29 18:40:59  truly a master at deranged cat photography; a ...
# 5  2012-11-02 22:28:16  Con afán de descubrir todo lo que pueda sobre ...
# 6  2011-11-29 15:50:47  Daily posts on UK music & culture 🇬🇧No copyrig...
# 7  2008-12-05 01:35:16  Revolution is what's for breakfast\nMerciless ...
# 8  2012-12-25 18:43:59  Known as ‘meow’ to three cat children, a pain ...
# 9  2013-11-14 11:44:48  Canadian gamer, writer, ranter, retweeter extr...
# 10 2020-04-20 21:42:28                   short & sweet just like my penis
# 11 2015-10-11 16:11:31  what do you mean you're at soup? - 18 - 🏳️‍🌈🏳️...
# 12 2017-08-18 21:17:32  Morning and Afternoon Traffic Reporter for Tod...
# 13 2011-03-24 05:49:52  Delay gratification. Maximize forethought. App...
# 14 2012-09-05 04:11:55  Howard U Alumna. 1913 🔺 Laughter is the best m...
# 15 2013-12-05 02:26:14
# 16 2018-12-20 14:47:19
# 17 2020-09-17 09:01:18  Facebook:Sandile Siva K'ganya Mamba-Lendze\niA...
# 18 2011-06-03 16:17:31  3rd and Long on @Sportsnet Radio Network is yo...
# 19 2017-09-03 18:37:44                       26. wife. mom. gamer. 🤷🏻‍♀️😊
#
#     userFollowerCt  userFriendsCt                       userLocation  \
# 0              604            329                                 🇩🇪
# 1             4569           4503            Living on Awabakal land
# 2             1124           2439
# 3                8            174
# 4              382            318           neither Akron nor Canton
# 5              198           1056
# 6            16625           8672                    London, England
# 7              755           1059                       Brooklyn, NY
# 8              455            328  Yorkshire and The Humber, England
# 9              114            272                    Ontario, Canada
# 10             446            579                         horny jail
# 11              66            259                 i mean i'm at soup
# 12             785            295                      Baltimore, MD
# 13            1794           1862                            In mine
# 14             541            714                      Las Vegas, NV
# 15             141            587
# 16             235            229
# 17             129            332                      Mzansi Africa
# 18            1026            787                             Canada
# 19              19            212
#
#    userTimezone
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11         None
# 12         None
# 13         None
# 14         None
# 15         None
# 16         None
# 17         None
# 18         None
# 19         None

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweetID          10000 non-null  int64
#  1   tweetText        10000 non-null  object
#  2   tweetRetweetCt   10000 non-null  int64
#  3   tweetFavoriteCt  10000 non-null  int64
#  4   tweetSource      10000 non-null  object
#  5   tweetCreated     10000 non-null  datetime64[ns]
#  6   userID           10000 non-null  int64
#  7   userScreen       10000 non-null  object
#  8   userName         10000 non-null  object
#  9   userCreateDt     10000 non-null  datetime64[ns]
#  10  userDesc         10000 non-null  object
#  11  userFollowerCt   10000 non-null  int64
#  12  userFriendsCt    10000 non-null  int64
#  13  userLocation     10000 non-null  object
#  14  userTimezone     0 non-null      object
# dtypes: datetime64[ns](2), int64(6), object(7)
# memory usage: 1.1+ MB

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
